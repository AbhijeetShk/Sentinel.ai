# %%
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /Users/Abhijeet/miniconda3/envs/ml_ossp/bin/python

# %%
df = pd.read_csv("../../dataset/HDFS_v1/preprocessed/anomaly_label.csv")
print(df.head())
print("Shape:", df.shape)
# Out:
#                     BlockId    Label
# 0  blk_-1608999687919862906   Normal
# 1   blk_7503483334202473044   Normal
# 2  blk_-3544583377289625738  Anomaly
# 3  blk_-9073992586687739851   Normal
# 4   blk_7854771516489510256   Normal
# Shape: (575061, 2)

# %%
df["Label"].value_counts()
# Out:
# Label
# Normal     558223
# Anomaly     16838
# Name: count, dtype: int64

# %%
df["Label"].value_counts(normalize=True)*100
# Out:
# Label
# Normal     97.071963
# Anomaly     2.928037
# Name: proportion, dtype: float64

# %%
events = pd.read_csv("../../dataset/HDFS_v1/preprocessed/Event_occurrence_matrix.csv")
events.shape
events.head()
# Out:
#                     BlockId    Label  Type  E1  E2   E3  E4  E5  E6  E7  ...  \
# 0  blk_-1608999687919862906  Success   NaN   0   0  203   0  10   7   0  ...
# 1   blk_7503483334202473044  Success   NaN   0   2    1   0   3   0   0  ...
# 2  blk_-3544583377289625738     Fail  21.0   0   0  203   0   3   0   0  ...
# 3  blk_-9073992586687739851  Success   NaN   0   3    0   0   3   0   0  ...
# 4   blk_7854771516489510256  Success   NaN   0   3    1  15   3   0   0  ...
#
#    E20  E21  E22  E23  E24  E25  E26  E27  E28  E29
# 0    0   10    1   10    0    4   10    0    0    0
# 1    0    3    1    3    0    0    3    0    0    0
# 2    1    3    1    3    0    0    3    0    0    0
# 3    0    3    1    3    0    0    3    0    0    0
# 4    0    3    1    3    0    0    3    0    0    0
#
# [5 rows x 32 columns]

# %%
merged = events.merge(df,on="BlockId")

# %%
merged.shape
# Out:
# (575061, 33)

# %%
merged.isnull().sum().sum()
# Out:
# np.int64(558223)

# %%
events.shape
# Out:
# (575061, 32)

# %%
df.shape
# Out:
# (575061, 2)

# %%
merged.shape
# Out:
# (575061, 33)

# %%
merged.isnull().sum().head()
# Out:
# BlockId         0
# Label_x         0
# Type       558223
# E1              0
# E2              0
# dtype: int64

# %%
merged= events.merge(df,on="BlockId",how="inner")
merged.isnull().sum().sum()
# Out:
# np.int64(558223)

# %%
merged.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Type       558223
# BlockId         0
# E23             0
# E17             0
# E18             0
# E19             0
# E20             0
# E21             0
# E22             0
# E24             0
# dtype: int64

# %%
merged.isnull().sum().sum()
# Out:
# np.int64(558223)

# %%
merged = merged.drop(columns =["Type"])

# %%
# merged.iloc[:, 1:].sum().describe()

# %%
# events.iloc[:, 1:].sum().describe()

# %%
# merged.iloc[:, 1:].describe()

# %%
df["Label"] = df["Label"].map({"Normal": 0, "Anomaly": 1})

# %%
df["Label"].value_counts()
# Out:
# Label
# 0    558223
# 1     16838
# Name: count, dtype: int64

# %%
df["Label"].value_counts()
# Out:
# Label
# 0    558223
# 1     16838
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x = merged.drop(["BlockId", "Label_y"], axis=1)
y = merged["Label_y"]
y = y.map({"Normal": 0, "Anomaly": 1})
x_train , x_test , y_train , y_test = train_test_split(
    x,y,test_size=0.2, stratify = y, random_state=42
)

# %%
print(merged.columns)
# Out:
# Index(['BlockId', 'Label_x', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8',
#        'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15', 'E16', 'E17', 'E18',
#        'E19', 'E20', 'E21', 'E22', 'E23', 'E24', 'E25', 'E26', 'E27', 'E28',
#        'E29', 'Label_y'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.shape
df.head()
# Out:
#                     BlockId  Label
# 0  blk_-1608999687919862906      0
# 1   blk_7503483334202473044      0
# 2  blk_-3544583377289625738      1
# 3  blk_-9073992586687739851      0
# 4   blk_7854771516489510256      0

# %%
events.shape
events.head()
# Out:
#                     BlockId    Label  Type  E1  E2   E3  E4  E5  E6  E7  ...  \
# 0  blk_-1608999687919862906  Success   NaN   0   0  203   0  10   7   0  ...
# 1   blk_7503483334202473044  Success   NaN   0   2    1   0   3   0   0  ...
# 2  blk_-3544583377289625738     Fail  21.0   0   0  203   0   3   0   0  ...
# 3  blk_-9073992586687739851  Success   NaN   0   3    0   0   3   0   0  ...
# 4   blk_7854771516489510256  Success   NaN   0   3    1  15   3   0   0  ...
#
#    E20  E21  E22  E23  E24  E25  E26  E27  E28  E29
# 0    0   10    1   10    0    4   10    0    0    0
# 1    0    3    1    3    0    0    3    0    0    0
# 2    1    3    1    3    0    0    3    0    0    0
# 3    0    3    1    3    0    0    3    0    0    0
# 4    0    3    1    3    0    0    3    0    0    0
#
# [5 rows x 32 columns]

# %%
merged.shape
merged.head()
# Out:
#                     BlockId  Label_x  E1  E2   E3  E4  E5  E6  E7  E8  ...  \
# 0  blk_-1608999687919862906  Success   0   0  203   0  10   7   0   0  ...
# 1   blk_7503483334202473044  Success   0   2    1   0   3   0   0   0  ...
# 2  blk_-3544583377289625738     Fail   0   0  203   0   3   0   0   0  ...
# 3  blk_-9073992586687739851  Success   0   3    0   0   3   0   0   0  ...
# 4   blk_7854771516489510256  Success   0   3    1  15   3   0   0   0  ...
#
#    E21  E22  E23  E24  E25  E26  E27  E28  E29  Label_y
# 0   10    1   10    0    4   10    0    0    0   Normal
# 1    3    1    3    0    0    3    0    0    0   Normal
# 2    3    1    3    0    0    3    0    0    0  Anomaly
# 3    3    1    3    0    0    3    0    0    0   Normal
# 4    3    1    3    0    0    3    0    0    0   Normal
#
# [5 rows x 32 columns]

# %%
merged.isnull().sum()
#events.isnull().sum()
# Out:
# BlockId    0
# Label_x    0
# E1         0
# E2         0
# E3         0
# E4         0
# E5         0
# E6         0
# E7         0
# E8         0
# E9         0
# E10        0
# E11        0
# E12        0
# E13        0
# E14        0
# E15        0
# E16        0
# E17        0
# E18        0
# E19        0
# E20        0
# E21        0
# E22        0
# E23        0
# E24        0
# E25        0
# E26        0
# E27        0
# E28        0
# E29        0
# Label_y    0
# dtype: int64

# %%
merged = merged.drop(columns = ["Label_x"])
merged = merged.rename(columns = {"Label_y":"Label"})

# %%
merged.head()
# Out:
#                     BlockId  E1  E2   E3  E4  E5  E6  E7  E8  E9  ...  E21  \
# 0  blk_-1608999687919862906   0   0  203   0  10   7   0   0   3  ...   10
# 1   blk_7503483334202473044   0   2    1   0   3   0   0   0   3  ...    3
# 2  blk_-3544583377289625738   0   0  203   0   3   0   0   0   3  ...    3
# 3  blk_-9073992586687739851   0   3    0   0   3   0   0   0   3  ...    3
# 4   blk_7854771516489510256   0   3    1  15   3   0   0   0   3  ...    3
#
#    E22  E23  E24  E25  E26  E27  E28  E29    Label
# 0    1   10    0    4   10    0    0    0   Normal
# 1    1    3    0    0    3    0    0    0   Normal
# 2    1    3    0    0    3    0    0    0  Anomaly
# 3    1    3    0    0    3    0    0    0   Normal
# 4    1    3    0    0    3    0    0    0   Normal
#
# [5 rows x 31 columns]

# %%
merged["Label"] = merged["Label"].map({"Normal": 0, "Anomaly": 1})

# %%
merged["Label"].value_counts()
# Out:
# Label
# 0    558223
# 1     16838
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x = merged.drop(["BlockId", "Label"], axis=1)
y = merged["Label"]
#y = y.map({"Normal": 0, "Anomaly": 1})
x_train , x_test , y_train , y_test = train_test_split(
    x,y,test_size=0.2, stratify = y, random_state=42
)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (460048, 29)
# (115013, 29)

# %%
sns.countplot(x="Label",data=merged)
plt.title("Class Distribution")
plt.show()

# %%
events_sum=x.sum()
events_sum.sort_values(ascending=False).head(10).plot(kind="bar")
plt.title("Top Event Frequencies")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(x.iloc[:, :20].corr(), cmap="coolwarm")
plt.title("Event Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(merged["E5"], bins=30)
plt.title("Distribution of Event E5")
plt.show()

# %%
'''We want to see how frequently certain events occur and how their values are distributed.
Choose a few events (for example the most frequent ones).
Find top events first'''
event_sums = x.sum()

event_sums.sort_values(ascending=False).head(10)
# Out:
# E5     1723232
# E26    1719741
# E11    1706679
# E9     1706514
# E21    1402047
# E23    1396174
# E22     575061
# E3      428726
# E4      356207
# E2      120036
# dtype: int64

# %%
'''What this tells you
You will see:
which events occur very frequently
which events are rare
whether distributions are skewed
This is important for anomaly detection.'''
top_events = x.sum().sort_values(ascending=False).head(10)

top_events.plot(kind="bar")

plt.title("Top 10 Most Frequent Log Events")
plt.xlabel("Event ID")
plt.ylabel("Frequency")
plt.show()

# %%
'''Variance tells us how much a feature changes.
Features with very low variance carry little information.
Compute variance'''
variance = x.var()
variance.sort_values().head(10)
#This shows lowest variance features.

variance.sort_values(ascending=False).head(10).plot(kind="pie")

plt.title("Top Features by Variance")
plt.xlabel("Event ID")
plt.ylabel("Variance")

plt.show()

# %%
normal_logs = merged[merged["Label"] == 0]
anomaly_logs = merged[merged["Label"] == 1]
normal_event_counts = normal_logs.drop(["BlockId","Label"], axis=1).sum()
anomaly_event_counts = anomaly_logs.drop(["BlockId","Label"], axis=1).sum()
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(normal_event_counts.values, label="Normal", color="blue")
plt.plot(anomaly_event_counts.values, label="Anomaly", color="red")

plt.title("Event Frequency Comparison: Normal vs Anomaly")
plt.xlabel("Event ID")
plt.ylabel("Frequency")

plt.legend()

plt.show()
'''This shows how event frequencies differ between normal and anomalous blocks.
It is very common in papers like DeepLog, LogBERT, LogAnomaly.'''
# Out:
# 'This shows how event frequencies differ between normal and anomalous blocks.\nIt is very common in papers like DeepLog, LogBERT, LogAnomaly.'

# %%
'''Replace E3 with any event.
This shows if an event behaves differently in anomalies.'''
plt.figure(figsize=(10,6))

sns.boxplot(x="Label", y="E3", data=merged)

plt.title("Event E3 Distribution by Class")
plt.show()

# %%
merged.to_csv("processed_hdfs.csv", index=False)
